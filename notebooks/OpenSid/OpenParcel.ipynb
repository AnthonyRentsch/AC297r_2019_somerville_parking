# %%
import rasterio
import matplotlib.pyplot as plt

# %%
dataset = rasterio.open('../../data/raster_parcel_test/parcel0.TIF')
plt.imshow(dataset.read(1))

# %%
dataset
# Out:
# <open DatasetReader name='../../data/raster_parcel_test/parcel0.TIF' mode='r'>
