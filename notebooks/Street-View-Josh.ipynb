# %%
from src.streetview import save_streetview_image, KEY
import pandas as pd
import numpy as np
import re
import time
from django.utils import text
from os import listdir
from os.path import isfile, join

# %%
# df = pd.read_csv('../data/street_view_sample/sample_residences_102219.csv')

# %%
def clean_address(adr, slugify = True):
    street_adr = adr.split(',')[0]
    fn = re.sub(' +','_',street_adr)
    if slugify:
        fn = text.slugify(fn)
    return fn + '.jpg'

# %%
# for address in df.ADDRESS_FOR_STREET_VIEW:
#     filename = f"../data/street_view_sample/{clean_address(address)}.jpg"
#     save_streetview_image(address, filename)

# %% [markdown]
# # Clean Data

# %%
df = pd.read_excel('../data/residence_addresses_googlestreetview.xlsx', sheet_name = 3)

print(len(df))
df = df[['MBL','SITE_ADDR']]

df.SITE_ADDR = df.SITE_ADDR.apply(lambda x: x.split('#')[0].strip().replace('  ',' '))

df = df.drop_duplicates()

print(len(df))

address_list = df.groupby('MBL')['SITE_ADDR'].apply(list).reset_index()

print(len(address_list))

def clean_addr(addr_list):
    if len(addr_list) == 0:
        return np.nan
    elif len(addr_list) == 1:
        return addr_list[0]
    else:
        for addr in addr_list:
            if '-' in addr:
                return addr
            if re.search('\d \d', addr):
                return re.sub('\d \d', lambda x: x.group(0).replace(' ','-'), addr)
            else:
                return addr_list[0]

address_list.SITE_ADDR = (
    address_list.SITE_ADDR
    .apply(clean_addr)
    .apply(lambda x: x + ', Somerville, MA')
)

print(len(address_list))

address_list.to_csv('../data/address_MBL.csv')
# Out:
# 17750
# 13770
# 12069
# 12069

# %% [markdown]
# # get list of addresses to download

# %%
files_already_dowloaded = [f for f in listdir("../data/street_view_all/") 
                           if isfile(join("../data/street_view_all/", f))]

files_already_dowloaded[0]

is_row_downloaded_new_names = (
    address_list.SITE_ADDR
    .apply(clean_address)
    .apply(lambda x: x in files_already_dowloaded)
)
print(sum(is_row_downloaded_new_names))

is_row_downloaded_old_names = (
    address_list.SITE_ADDR
    .apply(lambda x: clean_address(x, slugify = False))
    .apply(lambda x: x in files_already_dowloaded)
)
print(sum(is_row_downloaded_old_names))

address_list = address_list[
    ~ is_row_downloaded_old_names & ~ is_row_downloaded_new_names
]

address_list
# Out:
# '8_fairfax_st.jpg'

# %% [markdown]
# # Download Images

# %%
def check_for_file(dir_path, image_name):
    files_already_dowloaded = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]
    return image_name in files_already_dowloaded

# %%
for idx, address in enumerate(address_list.SITE_ADDR):
    street_view_all = "../data/street_view_all/"
    image_name = clean_address(address)
    filename = street_view_all + image_name
    save_streetview_image(address, filename)
    
    file_exists = (
        check_for_file(street_view_all, clean_address(address)) 
        or check_for_file(street_view_all, clean_address(address, slugify = False))
    )
    if not file_exists:
        break
        
    if idx % 10 == 0:
        print(f"{idx+1}/{len(address_list)} images downloaded")
# Out:
# 1/8481 images downloaded
# 11/8481 images downloaded
# 21/8481 images downloaded
# 31/8481 images downloaded
# 41/8481 images downloaded
# 51/8481 images downloaded
# 61/8481 images downloaded
# 71/8481 images downloaded
# 81/8481 images downloaded
# 91/8481 images downloaded
# 101/8481 images downloaded
# 111/8481 images downloaded
# 121/8481 images downloaded
# 131/8481 images downloaded
# 141/8481 images downloaded
# 151/8481 images downloaded
# 161/8481 images downloaded
# 171/8481 images downloaded
# 181/8481 images downloaded
# 191/8481 images downloaded
# 201/8481 images downloaded
# 211/8481 images downloaded
# 221/8481 images downloaded
# 231/8481 images downloaded
# 241/8481 images downloaded
# 251/8481 images downloaded
# 261/8481 images downloaded
# 271/8481 images downloaded
# 281/8481 images downloaded
# 291/8481 images downloaded
# 301/8481 images downloaded
# 311/8481 images downloaded
# 321/8481 images downloaded
# 331/8481 images downloaded
# 341/8481 images downloaded
# 351/8481 images downloaded
# 361/8481 images downloaded
# 371/8481 images downloaded
# 381/8481 images downloaded
# 391/8481 images downloaded
# 401/8481 images downloaded
# 411/8481 images downloaded
# 421/8481 images downloaded
# 431/8481 images downloaded
# 441/8481 images downloaded
# 451/8481 images downloaded
# 461/8481 images downloaded
# 471/8481 images downloaded
# 481/8481 images downloaded
# 491/8481 images downloaded
# 501/8481 images downloaded
# 511/8481 images downloaded
# 521/8481 images downloaded
# 531/8481 images downloaded
# 541/8481 images downloaded
# 551/8481 images downloaded
# 561/8481 images downloaded
# 571/8481 images downloaded
# 581/8481 images downloaded
# 591/8481 images downloaded
# 601/8481 images downloaded
# 611/8481 images downloaded
# 621/8481 images downloaded
# 631/8481 images downloaded
# 641/8481 images downloaded
# 651/8481 images downloaded
# 661/8481 images downloaded
# 671/8481 images downloaded
# 681/8481 images downloaded
# 691/8481 images downloaded
# 701/8481 images downloaded
# 711/8481 images downloaded
# 721/8481 images downloaded
# 731/8481 images downloaded
# 741/8481 images downloaded
# 751/8481 images downloaded
# 761/8481 images downloaded
# 771/8481 images downloaded
# 781/8481 images downloaded
# 791/8481 images downloaded
# 801/8481 images downloaded
# 811/8481 images downloaded
# 821/8481 images downloaded
# 831/8481 images downloaded
# 841/8481 images downloaded
# 851/8481 images downloaded
# 861/8481 images downloaded
# 871/8481 images downloaded
# 881/8481 images downloaded
# 891/8481 images downloaded
# 901/8481 images downloaded
# 911/8481 images downloaded
# 921/8481 images downloaded
# 931/8481 images downloaded
# 941/8481 images downloaded
# 951/8481 images downloaded
# 961/8481 images downloaded
# 971/8481 images downloaded
# 981/8481 images downloaded
# 991/8481 images downloaded
# 1001/8481 images downloaded
# 1011/8481 images downloaded
# 1021/8481 images downloaded
# 1031/8481 images downloaded
# 1041/8481 images downloaded
# 1051/8481 images downloaded
# 1061/8481 images downloaded
# 1071/8481 images downloaded
# 1081/8481 images downloaded
# 1091/8481 images downloaded
# 1101/8481 images downloaded
# 1111/8481 images downloaded
# 1121/8481 images downloaded
# 1131/8481 images downloaded
# 1141/8481 images downloaded
# 1151/8481 images downloaded
# 1161/8481 images downloaded
# 1171/8481 images downloaded
# 1181/8481 images downloaded
# 1191/8481 images downloaded
# 1201/8481 images downloaded
# 1211/8481 images downloaded
# 1221/8481 images downloaded
# 1231/8481 images downloaded
# 1241/8481 images downloaded
# 1251/8481 images downloaded
# 1261/8481 images downloaded
# 1271/8481 images downloaded
# 1281/8481 images downloaded
# 1291/8481 images downloaded
# 1301/8481 images downloaded
# 1311/8481 images downloaded
# 1321/8481 images downloaded
# 1331/8481 images downloaded
# 1341/8481 images downloaded
# 1351/8481 images downloaded
# 1361/8481 images downloaded
# 1371/8481 images downloaded
# 1381/8481 images downloaded
# 1391/8481 images downloaded
# 1401/8481 images downloaded
# 1411/8481 images downloaded
# 1421/8481 images downloaded
# 1431/8481 images downloaded
# 1441/8481 images downloaded
# 1451/8481 images downloaded
# 1461/8481 images downloaded
# 1471/8481 images downloaded
# 1481/8481 images downloaded
# 1491/8481 images downloaded
# 1501/8481 images downloaded
# 1511/8481 images downloaded
# 1521/8481 images downloaded
# 1531/8481 images downloaded
# 1541/8481 images downloaded
# 1551/8481 images downloaded
# 1561/8481 images downloaded
# 1571/8481 images downloaded
# 1581/8481 images downloaded
# 1591/8481 images downloaded
# 1601/8481 images downloaded
# 1611/8481 images downloaded
# 1621/8481 images downloaded
# 1631/8481 images downloaded
# 1641/8481 images downloaded
# 1651/8481 images downloaded
# 1661/8481 images downloaded
# 1671/8481 images downloaded
# 1681/8481 images downloaded
# 1691/8481 images downloaded
# 1701/8481 images downloaded
# 1711/8481 images downloaded
# 1721/8481 images downloaded
# 1731/8481 images downloaded
# 1741/8481 images downloaded
# 1751/8481 images downloaded
# 1761/8481 images downloaded
# 1771/8481 images downloaded
# 1781/8481 images downloaded
# 1791/8481 images downloaded
# 1801/8481 images downloaded
# 1811/8481 images downloaded
# 1821/8481 images downloaded
# 1831/8481 images downloaded
# 1841/8481 images downloaded
# 1851/8481 images downloaded
# 1861/8481 images downloaded
# 1871/8481 images downloaded
# 1881/8481 images downloaded
# 1891/8481 images downloaded
# 1901/8481 images downloaded
# 1911/8481 images downloaded
# 1921/8481 images downloaded
# 1931/8481 images downloaded
# 1941/8481 images downloaded
# 1951/8481 images downloaded
# 1961/8481 images downloaded
# 1971/8481 images downloaded
# 1981/8481 images downloaded
# 1991/8481 images downloaded
# 2001/8481 images downloaded
# 2011/8481 images downloaded
# 2021/8481 images downloaded
# 2031/8481 images downloaded
# 2041/8481 images downloaded
# 2051/8481 images downloaded
# 2061/8481 images downloaded
# 2071/8481 images downloaded
# 2081/8481 images downloaded
# 2091/8481 images downloaded
# 2101/8481 images downloaded
# 2111/8481 images downloaded
# 2121/8481 images downloaded
# 2131/8481 images downloaded
# 2141/8481 images downloaded
# 2151/8481 images downloaded
# 2161/8481 images downloaded
# 2171/8481 images downloaded
# 2181/8481 images downloaded
# 2191/8481 images downloaded
# 2201/8481 images downloaded
# 2211/8481 images downloaded
# 2221/8481 images downloaded
# 2231/8481 images downloaded
# 2241/8481 images downloaded
# 2251/8481 images downloaded
# 2261/8481 images downloaded
# 2271/8481 images downloaded
# 2281/8481 images downloaded
# 2291/8481 images downloaded
# 2301/8481 images downloaded
# 2311/8481 images downloaded
# 2321/8481 images downloaded
# 2331/8481 images downloaded
# 2341/8481 images downloaded
# 2351/8481 images downloaded
# 2361/8481 images downloaded
# 2371/8481 images downloaded
# 2381/8481 images downloaded
# 2391/8481 images downloaded
# 2401/8481 images downloaded
# 2411/8481 images downloaded
# 2421/8481 images downloaded
# 2431/8481 images downloaded
# 2441/8481 images downloaded
# 2451/8481 images downloaded
# 2461/8481 images downloaded
# 2471/8481 images downloaded
# 2481/8481 images downloaded
# 2491/8481 images downloaded
# 2501/8481 images downloaded
# 2511/8481 images downloaded
# 2521/8481 images downloaded
# 2531/8481 images downloaded
# 2541/8481 images downloaded
# 2551/8481 images downloaded
# 2561/8481 images downloaded
# 2571/8481 images downloaded
# 2581/8481 images downloaded
# 2591/8481 images downloaded
# 2601/8481 images downloaded
# 2611/8481 images downloaded
# 2621/8481 images downloaded
# 2631/8481 images downloaded
# 2641/8481 images downloaded
# 2651/8481 images downloaded
# 2661/8481 images downloaded
# 2671/8481 images downloaded
# 2681/8481 images downloaded
# 2691/8481 images downloaded
# 2701/8481 images downloaded
# 2711/8481 images downloaded
# 2721/8481 images downloaded
# 2731/8481 images downloaded
# 2741/8481 images downloaded
# 2751/8481 images downloaded
# 2761/8481 images downloaded
# 2771/8481 images downloaded
# 2781/8481 images downloaded
# 2791/8481 images downloaded
# 2801/8481 images downloaded
# 2811/8481 images downloaded
# 2821/8481 images downloaded
# 2831/8481 images downloaded
# 2841/8481 images downloaded
# 2851/8481 images downloaded
# 2861/8481 images downloaded
# 2871/8481 images downloaded
# 2881/8481 images downloaded
# 2891/8481 images downloaded
# 2901/8481 images downloaded
# 2911/8481 images downloaded
# 2921/8481 images downloaded
# 2931/8481 images downloaded
# 2941/8481 images downloaded
# 2951/8481 images downloaded
# 2961/8481 images downloaded
# 2971/8481 images downloaded
# 2981/8481 images downloaded
# 2991/8481 images downloaded
# 3001/8481 images downloaded
# 3011/8481 images downloaded
# 3021/8481 images downloaded
# 3031/8481 images downloaded
# 3041/8481 images downloaded
# 3051/8481 images downloaded
# 3061/8481 images downloaded
# 3071/8481 images downloaded
# 3081/8481 images downloaded
# 3091/8481 images downloaded
# 3101/8481 images downloaded
# 3111/8481 images downloaded
# 3121/8481 images downloaded
# 3131/8481 images downloaded
# 3141/8481 images downloaded
# 3151/8481 images downloaded
# 3161/8481 images downloaded
# 3171/8481 images downloaded
# 3181/8481 images downloaded
# 3191/8481 images downloaded
# 3201/8481 images downloaded
# 3211/8481 images downloaded
# 3221/8481 images downloaded
# 3231/8481 images downloaded
# 3241/8481 images downloaded
# 3251/8481 images downloaded
# 3261/8481 images downloaded
# 3271/8481 images downloaded
# 3281/8481 images downloaded
# 3291/8481 images downloaded
# 3301/8481 images downloaded
# 3311/8481 images downloaded
# 3321/8481 images downloaded
# 3331/8481 images downloaded
# 3341/8481 images downloaded
# 3351/8481 images downloaded
# 3361/8481 images downloaded
# 3371/8481 images downloaded
# 3381/8481 images downloaded
# 3391/8481 images downloaded
# 3401/8481 images downloaded
# 3411/8481 images downloaded
# 3421/8481 images downloaded
# 3431/8481 images downloaded
# 3441/8481 images downloaded
# 3451/8481 images downloaded
# 3461/8481 images downloaded
# 3471/8481 images downloaded
# 3481/8481 images downloaded
# 3491/8481 images downloaded
# 3501/8481 images downloaded
# 3511/8481 images downloaded
# 3521/8481 images downloaded
# 3531/8481 images downloaded
# 3541/8481 images downloaded
# 3551/8481 images downloaded
# 3561/8481 images downloaded
# 3571/8481 images downloaded
# 3581/8481 images downloaded
# 3591/8481 images downloaded
# 3601/8481 images downloaded
# 3611/8481 images downloaded
# 3621/8481 images downloaded
# 3631/8481 images downloaded
# 3641/8481 images downloaded
# 3651/8481 images downloaded
# 3661/8481 images downloaded
# 3671/8481 images downloaded
# 3681/8481 images downloaded
# 3691/8481 images downloaded
# 3701/8481 images downloaded
# 3711/8481 images downloaded
# 3721/8481 images downloaded
# 3731/8481 images downloaded
# 3741/8481 images downloaded
# 3751/8481 images downloaded
# 3761/8481 images downloaded
# 3771/8481 images downloaded
# 3781/8481 images downloaded
# 3791/8481 images downloaded
# 3801/8481 images downloaded
# 3811/8481 images downloaded
# 3821/8481 images downloaded
# 3831/8481 images downloaded
# 3841/8481 images downloaded
# 3851/8481 images downloaded
# 3861/8481 images downloaded
# 3871/8481 images downloaded
# 3881/8481 images downloaded
# 3891/8481 images downloaded
# 3901/8481 images downloaded
# 3911/8481 images downloaded
# 3921/8481 images downloaded
# 3931/8481 images downloaded
# 3941/8481 images downloaded
# 3951/8481 images downloaded
# 3961/8481 images downloaded
# 3971/8481 images downloaded
# 3981/8481 images downloaded
# 3991/8481 images downloaded
# 4001/8481 images downloaded
# 4011/8481 images downloaded
# 4021/8481 images downloaded
# 4031/8481 images downloaded
# 4041/8481 images downloaded
# 4051/8481 images downloaded
# 4061/8481 images downloaded
# 4071/8481 images downloaded
# 4081/8481 images downloaded
# 4091/8481 images downloaded
# 4101/8481 images downloaded
# 4111/8481 images downloaded
# 4121/8481 images downloaded
# 4131/8481 images downloaded
# 4141/8481 images downloaded
# 4151/8481 images downloaded
# 4161/8481 images downloaded
# 4171/8481 images downloaded
# 4181/8481 images downloaded
# 4191/8481 images downloaded
# 4201/8481 images downloaded
# 4211/8481 images downloaded
# 4221/8481 images downloaded
# 4231/8481 images downloaded
# 4241/8481 images downloaded
# 4251/8481 images downloaded
# 4261/8481 images downloaded
# 4271/8481 images downloaded
# 4281/8481 images downloaded
# 4291/8481 images downloaded
# 4301/8481 images downloaded
# 4311/8481 images downloaded
# 4321/8481 images downloaded
# 4331/8481 images downloaded
# 4341/8481 images downloaded
# 4351/8481 images downloaded
# 4361/8481 images downloaded
# 4371/8481 images downloaded
# 4381/8481 images downloaded
# 4391/8481 images downloaded
# 4401/8481 images downloaded
# 4411/8481 images downloaded
# 4421/8481 images downloaded
# 4431/8481 images downloaded
# 4441/8481 images downloaded
# 4451/8481 images downloaded
# 4461/8481 images downloaded
# 4471/8481 images downloaded
# 4481/8481 images downloaded
# 4491/8481 images downloaded
# 4501/8481 images downloaded
# 4511/8481 images downloaded
# 4521/8481 images downloaded
# 4531/8481 images downloaded
# 4541/8481 images downloaded
# 4551/8481 images downloaded
# 4561/8481 images downloaded
# 4571/8481 images downloaded
# 4581/8481 images downloaded
# 4591/8481 images downloaded
# 4601/8481 images downloaded
# 4611/8481 images downloaded
# 4621/8481 images downloaded
# 4631/8481 images downloaded
# 4641/8481 images downloaded
# 4651/8481 images downloaded
# 4661/8481 images downloaded
# 4671/8481 images downloaded
# 4681/8481 images downloaded
# 4691/8481 images downloaded
# 4701/8481 images downloaded
# 4711/8481 images downloaded
# 4721/8481 images downloaded
# 4731/8481 images downloaded
# 4741/8481 images downloaded
# 4751/8481 images downloaded
# 4761/8481 images downloaded
# 4771/8481 images downloaded
# 4781/8481 images downloaded
# 4791/8481 images downloaded
# 4801/8481 images downloaded
# 4811/8481 images downloaded
# 4821/8481 images downloaded
# 4831/8481 images downloaded
# 4841/8481 images downloaded
# 4851/8481 images downloaded
# 4861/8481 images downloaded
# 4871/8481 images downloaded
# 4881/8481 images downloaded
# 4891/8481 images downloaded
# 4901/8481 images downloaded
# 4911/8481 images downloaded
# 4921/8481 images downloaded
# 4931/8481 images downloaded
# 4941/8481 images downloaded
# 4951/8481 images downloaded
# 4961/8481 images downloaded
# 4971/8481 images downloaded
# 4981/8481 images downloaded
# 4991/8481 images downloaded
# 5001/8481 images downloaded
# 5011/8481 images downloaded
# 5021/8481 images downloaded
# 5031/8481 images downloaded
# 5041/8481 images downloaded
# 5051/8481 images downloaded
# 5061/8481 images downloaded
# 5071/8481 images downloaded
# 5081/8481 images downloaded
# 5091/8481 images downloaded
# 5101/8481 images downloaded
# 5111/8481 images downloaded
# 5121/8481 images downloaded
# 5131/8481 images downloaded
# 5141/8481 images downloaded
# 5151/8481 images downloaded
# 5161/8481 images downloaded
# 5171/8481 images downloaded
# 5181/8481 images downloaded
# 5191/8481 images downloaded
# 5201/8481 images downloaded
# 5211/8481 images downloaded
# 5221/8481 images downloaded
# 5231/8481 images downloaded
# 5241/8481 images downloaded
# 5251/8481 images downloaded
# 5261/8481 images downloaded
# 5271/8481 images downloaded
# 5281/8481 images downloaded
# 5291/8481 images downloaded
# 5301/8481 images downloaded
# 5311/8481 images downloaded
# 5321/8481 images downloaded
# 5331/8481 images downloaded
# 5341/8481 images downloaded
# 5351/8481 images downloaded
# 5361/8481 images downloaded
# 5371/8481 images downloaded
# 5381/8481 images downloaded
# 5391/8481 images downloaded
# 5401/8481 images downloaded
# 5411/8481 images downloaded
# 5421/8481 images downloaded
# 5431/8481 images downloaded
# 5441/8481 images downloaded
# 5451/8481 images downloaded
# 5461/8481 images downloaded
# 5471/8481 images downloaded
# 5481/8481 images downloaded
# 5491/8481 images downloaded
# 5501/8481 images downloaded
# 5511/8481 images downloaded
# 5521/8481 images downloaded
# 5531/8481 images downloaded
# 5541/8481 images downloaded
# 5551/8481 images downloaded
# 5561/8481 images downloaded
# 5571/8481 images downloaded
# 5581/8481 images downloaded
# 5591/8481 images downloaded
# 5601/8481 images downloaded
# 5611/8481 images downloaded
# 5621/8481 images downloaded
# 5631/8481 images downloaded
# 5641/8481 images downloaded
# 5651/8481 images downloaded
# 5661/8481 images downloaded
# 5671/8481 images downloaded
# 5681/8481 images downloaded
# 5691/8481 images downloaded
# 5701/8481 images downloaded
# 5711/8481 images downloaded
# 5721/8481 images downloaded
# 5731/8481 images downloaded
# 5741/8481 images downloaded
# 5751/8481 images downloaded
# 5761/8481 images downloaded
# 5771/8481 images downloaded
# 5781/8481 images downloaded
# 5791/8481 images downloaded
# 5801/8481 images downloaded
# 5811/8481 images downloaded
# 5821/8481 images downloaded
# 5831/8481 images downloaded
# 5841/8481 images downloaded
# 5851/8481 images downloaded
# 5861/8481 images downloaded
# 5871/8481 images downloaded
# 5881/8481 images downloaded
# 5891/8481 images downloaded
# 5901/8481 images downloaded
# 5911/8481 images downloaded
# 5921/8481 images downloaded
# 5931/8481 images downloaded
# 5941/8481 images downloaded
# 5951/8481 images downloaded
# 5961/8481 images downloaded
# 5971/8481 images downloaded
# 5981/8481 images downloaded
# 5991/8481 images downloaded
# 6001/8481 images downloaded
# 6011/8481 images downloaded
# 6021/8481 images downloaded
# 6031/8481 images downloaded
# 6041/8481 images downloaded
# 6051/8481 images downloaded
# 6061/8481 images downloaded
# 6071/8481 images downloaded
# 6081/8481 images downloaded
# 6091/8481 images downloaded
# 6101/8481 images downloaded
# 6111/8481 images downloaded
# 6121/8481 images downloaded
# 6131/8481 images downloaded
# 6141/8481 images downloaded
# 6151/8481 images downloaded
# 6161/8481 images downloaded
# 6171/8481 images downloaded
# 6181/8481 images downloaded
# 6191/8481 images downloaded
# 6201/8481 images downloaded
# 6211/8481 images downloaded
# 6221/8481 images downloaded
# 6231/8481 images downloaded
# 6241/8481 images downloaded
# 6251/8481 images downloaded
# 6261/8481 images downloaded
# 6271/8481 images downloaded
# 6281/8481 images downloaded
# 6291/8481 images downloaded
# 6301/8481 images downloaded
# 6311/8481 images downloaded
# 6321/8481 images downloaded
# 6331/8481 images downloaded
# 6341/8481 images downloaded
# 6351/8481 images downloaded
# 6361/8481 images downloaded
# 6371/8481 images downloaded
# 6381/8481 images downloaded
# 6391/8481 images downloaded
# 6401/8481 images downloaded
# 6411/8481 images downloaded
# 6421/8481 images downloaded
# 6431/8481 images downloaded
# 6441/8481 images downloaded
# 6451/8481 images downloaded
# 6461/8481 images downloaded
# 6471/8481 images downloaded
# 6481/8481 images downloaded
# 6491/8481 images downloaded
# 6501/8481 images downloaded
# 6511/8481 images downloaded
# 6521/8481 images downloaded
# 6531/8481 images downloaded
# 6541/8481 images downloaded
# 6551/8481 images downloaded
# 6561/8481 images downloaded
# 6571/8481 images downloaded
# 6581/8481 images downloaded
# 6591/8481 images downloaded
# 6601/8481 images downloaded
# 6611/8481 images downloaded
# 6621/8481 images downloaded
# 6631/8481 images downloaded
# 6641/8481 images downloaded
# 6651/8481 images downloaded
# 6661/8481 images downloaded
# 6671/8481 images downloaded
# 6681/8481 images downloaded
# 6691/8481 images downloaded
# 6701/8481 images downloaded
# 6711/8481 images downloaded
# 6721/8481 images downloaded
# 6731/8481 images downloaded
# 6741/8481 images downloaded
# 6751/8481 images downloaded
# 6761/8481 images downloaded
# 6771/8481 images downloaded
# 6781/8481 images downloaded
# 6791/8481 images downloaded
# 6801/8481 images downloaded
# 6811/8481 images downloaded
# 6821/8481 images downloaded
# 6831/8481 images downloaded
# 6841/8481 images downloaded
# 6851/8481 images downloaded
# 6861/8481 images downloaded
# 6871/8481 images downloaded
# 6881/8481 images downloaded
# 6891/8481 images downloaded
# 6901/8481 images downloaded
# 6911/8481 images downloaded
# 6921/8481 images downloaded
# 6931/8481 images downloaded
# 6941/8481 images downloaded
# 6951/8481 images downloaded
# 6961/8481 images downloaded
# 6971/8481 images downloaded
# 6981/8481 images downloaded
# 6991/8481 images downloaded
# 7001/8481 images downloaded
# 7011/8481 images downloaded
# 7021/8481 images downloaded
# 7031/8481 images downloaded
# 7041/8481 images downloaded
# 7051/8481 images downloaded
# 7061/8481 images downloaded
# 7071/8481 images downloaded
# 7081/8481 images downloaded
# 7091/8481 images downloaded
# 7101/8481 images downloaded
# 7111/8481 images downloaded
# 7121/8481 images downloaded
# 7131/8481 images downloaded
# 7141/8481 images downloaded
# 7151/8481 images downloaded
# 7161/8481 images downloaded
# 7171/8481 images downloaded
# 7181/8481 images downloaded
# 7191/8481 images downloaded
# 7201/8481 images downloaded
# 7211/8481 images downloaded
# 7221/8481 images downloaded
# 7231/8481 images downloaded
# 7241/8481 images downloaded
# 7251/8481 images downloaded
# 7261/8481 images downloaded
# 7271/8481 images downloaded
# 7281/8481 images downloaded
# 7291/8481 images downloaded
# 7301/8481 images downloaded
# 7311/8481 images downloaded
# 7321/8481 images downloaded
# 7331/8481 images downloaded
# 7341/8481 images downloaded
# 7351/8481 images downloaded
# 7361/8481 images downloaded
# 7371/8481 images downloaded
# 7381/8481 images downloaded
# 7391/8481 images downloaded
# 7401/8481 images downloaded
# 7411/8481 images downloaded
# 7421/8481 images downloaded
# 7431/8481 images downloaded
# 7441/8481 images downloaded
# 7451/8481 images downloaded
# 7461/8481 images downloaded
# 7471/8481 images downloaded
# 7481/8481 images downloaded
# 7491/8481 images downloaded
# 7501/8481 images downloaded
# 7511/8481 images downloaded
# 7521/8481 images downloaded
# 7531/8481 images downloaded
# 7541/8481 images downloaded
# 7551/8481 images downloaded
# 7561/8481 images downloaded
# 7571/8481 images downloaded
# 7581/8481 images downloaded
# 7591/8481 images downloaded
# 7601/8481 images downloaded
# 7611/8481 images downloaded
# 7621/8481 images downloaded
# 7631/8481 images downloaded
# 7641/8481 images downloaded
# 7651/8481 images downloaded
# 7661/8481 images downloaded
# 7671/8481 images downloaded
# 7681/8481 images downloaded
# 7691/8481 images downloaded
# 7701/8481 images downloaded
# 7711/8481 images downloaded
# 7721/8481 images downloaded
# 7731/8481 images downloaded
# 7741/8481 images downloaded
# 7751/8481 images downloaded
# 7761/8481 images downloaded
# 7771/8481 images downloaded
# 7781/8481 images downloaded
# 7791/8481 images downloaded
# 7801/8481 images downloaded
# 7811/8481 images downloaded
# 7821/8481 images downloaded
# 7831/8481 images downloaded
# 7841/8481 images downloaded
# 7851/8481 images downloaded
# 7861/8481 images downloaded
# 7871/8481 images downloaded
# 7881/8481 images downloaded
# 7891/8481 images downloaded
# 7901/8481 images downloaded
# 7911/8481 images downloaded
# 7921/8481 images downloaded
# 7931/8481 images downloaded
# 7941/8481 images downloaded
# 7951/8481 images downloaded
# 7961/8481 images downloaded
# 7971/8481 images downloaded
# 7981/8481 images downloaded
# 7991/8481 images downloaded
# 8001/8481 images downloaded
# 8011/8481 images downloaded
# 8021/8481 images downloaded
# 8031/8481 images downloaded
# 8041/8481 images downloaded
# 8051/8481 images downloaded
# 8061/8481 images downloaded
# 8071/8481 images downloaded
# 8081/8481 images downloaded
# 8091/8481 images downloaded
# 8101/8481 images downloaded
# 8111/8481 images downloaded
# 8121/8481 images downloaded
# 8131/8481 images downloaded
# 8141/8481 images downloaded
# 8151/8481 images downloaded
# 8161/8481 images downloaded
# 8171/8481 images downloaded
# 8181/8481 images downloaded
# 8191/8481 images downloaded
# 8201/8481 images downloaded
# 8211/8481 images downloaded
# 8221/8481 images downloaded
# 8231/8481 images downloaded
# 8241/8481 images downloaded
# 8251/8481 images downloaded
# 8261/8481 images downloaded
# 8271/8481 images downloaded
# 8281/8481 images downloaded
# 8291/8481 images downloaded
# 8301/8481 images downloaded
# 8311/8481 images downloaded
# 8321/8481 images downloaded
# 8331/8481 images downloaded
# 8341/8481 images downloaded
# 8351/8481 images downloaded
# 8361/8481 images downloaded
# 8371/8481 images downloaded
# 8381/8481 images downloaded
# 8391/8481 images downloaded
# 8401/8481 images downloaded
# 8411/8481 images downloaded
# 8421/8481 images downloaded
# 8431/8481 images downloaded
# 8441/8481 images downloaded
# 8451/8481 images downloaded
# 8461/8481 images downloaded
# 8471/8481 images downloaded
# 8481/8481 images downloaded
